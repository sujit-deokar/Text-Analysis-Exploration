# %%
import pandas as pd
import numpy as np

# %%
In_data = pd.read_csv('./COVID_TextDataset/Corona_NLP_train.csv',encoding='latin')
In_data.head(3)
# Out:
#    UserName  ScreenName   Location     TweetAt  \
# 0      3799       48751     London  16-03-2020
# 1      3800       48752         UK  16-03-2020
# 2      3801       48753  Vagabonds  16-03-2020
#
#                                        OriginalTweet Sentiment
# 0  @MeNyrbie @Phil_Gahan @Chrisitv https://t.co/i...   Neutral
# 1  advice Talk to your neighbours family to excha...  Positive
# 2  Coronavirus Australia: Woolworths to give elde...  Positive

# %%
In_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41157 entries, 0 to 41156
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   UserName       41157 non-null  int64
#  1   ScreenName     41157 non-null  int64
#  2   Location       32567 non-null  object
#  3   TweetAt        41157 non-null  object
#  4   OriginalTweet  41157 non-null  object
#  5   Sentiment      41157 non-null  object
# dtypes: int64(2), object(4)
# memory usage: 1.9+ MB

# %%
In_data['OriginalTweet'].str.len().hist()
# Out:
# <AxesSubplot: >

# %%
In_data['OriginalTweet'].str.split().map(lambda x: len(x)).hist()
# Out:
# <AxesSubplot: >

# %%
import nltk
nltk.download('stopwords')
stop=set(stopwords.words('english'))
# Out:
# [nltk_data] Error loading stopwords: <urlopen error [SSL:
# [nltk_data]     CERTIFICATE_VERIFY_FAILED] certificate verify failed:
# [nltk_data]     unable to get local issuer certificate (_ssl.c:1129)>
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 3
#       1 import nltk
#       2 nltk.download('stopwords')
# ----> 3 stop=set(stopwords.words('english'))
#
# NameError: name 'stopwords' is not defined

# %%
corpus=[]
new= In_data['headline_text'].str.split()
new=new.values.tolist()
corpus=[word for i in new for word in i]

from collections import defaultdict
dic=defaultdict(int)
for word in corpus:
    if word in stop:
        dic[word]+=1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 2
#       1 corpus=[]
# ----> 2 new= news['headline_text'].str.split()
#       3 new=new.values.tolist()
#       4 corpus=[word for i in new for word in i]
#
# NameError: name 'news' is not defined
